# %% [markdown]
# # Anomaly detection for clickstream data

# %% [markdown]
# ## SageMaker Random Cut Forest

# %%
# %store -r urls url_new css streams

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import boto3
import botocore
import sagemaker
import sys

# %% [markdown]
# ### Data resampling
#
# We will use aggagated timeseries with 3 features of the number of visited urls, the number of visitors, and the numbor of clicks in 1 minute.

# %%
r = css.set_index('timestamp').resample('1T')
s = r.nunique()[['url','user_session_id']]
s['clicks'] = r.count()['clickstream_id']
s.columns = ['urls','users','clicks']
s.head()
# Out:
#                      urls  users  clicks
# timestamp
# 2012-03-01 00:00:00     3      4       5
# 2012-03-01 00:01:00     2      3       4
# 2012-03-01 00:02:00     1      4       4
# 2012-03-01 00:03:00     4      4       5
# 2012-03-01 00:04:00     5      6       9

# %% [markdown]
# - Plot the series

# %%
plt.figure(figsize=(20,5))
plt.plot(s)
plt.show()

# %% [markdown]
# ### RCF Training
#
# Then train the model with SageMaker built-in RandomCutForest algorithm

# %%
from sagemaker import RandomCutForest

session = sagemaker.Session()
bucket = session.default_bucket()
prefix = 'rcf-clickstream'
execution_role = sagemaker.get_execution_role()

# specify general training job information
rcf = RandomCutForest(role=execution_role,
                      train_instance_count=1,
                      train_instance_type='ml.m4.xlarge',
                      data_location='s3://{}/{}/'.format(bucket, prefix),
                      output_path='s3://{}/{}/output'.format(bucket, prefix),
                      num_samples_per_tree=512,
                      num_trees=50)

# automatically upload the training data to S3 and run the training job
rcf.fit(rcf.record_set(s.to_numpy()))
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 2020-08-16 12:54:52 Starting - Starting the training job...
# 2020-08-16 12:54:54 Starting - Launching requested ML instances......
# 2020-08-16 12:56:08 Starting - Preparing the instances for training......
# 2020-08-16 12:57:08 Downloading - Downloading input data...
# 2020-08-16 12:57:24 Training - Downloading the training image......
# 2020-08-16 12:58:49 Uploading - Uploading generated training model
# 2020-08-16 12:58:49 Completed - Training job completed
# Docker entrypoint called with argument(s): train
# Running default environment configuration script
# /opt/amazon/lib/python2.7/site-packages/scipy/_lib/_numpy_compat.py:10: DeprecationWarning: Importing from numpy.testing.nosetester is deprecated, import from numpy.testing instead.
#   from numpy.testing.nosetester import import_nose
# /opt/amazon/lib/python2.7/site-packages/scipy/stats/morestats.py:12: DeprecationWarning: Importing from numpy.testing.decorators is deprecated, import from numpy.testing instead.
#   from numpy.testing.decorators import setastest
# [08/16/2020 12:58:40 INFO 140692203804480] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-conf.json: {u'_ftp_port': 8999, u'num_samples_per_tree': 256, u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'_log_level': u'info', u'_kvstore': u'dist_async', u'force_dense': u'true', u'epochs': 1, u'num_trees': 100, u'eval_metrics': [u'accuracy', u'precision_recall_fscore'], u'_num_kv_servers': u'auto', u'mini_batch_size': 1000}
# [08/16/2020 12:58:40 INFO 140692203804480] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'mini_batch_size': u'1000', u'feature_dim': u'3', u'num_samples_per_tree': u'512', u'num_trees': u'50'}
# [08/16/2020 12:58:40 INFO 140692203804480] Final configuration: {u'_ftp_port': 8999, u'num_samples_per_tree': u'512', u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'_log_level': u'info', u'_kvstore': u'dist_async', u'force_dense': u'true', u'epochs': 1, u'feature_dim': u'3', u'num_trees': u'50', u'eval_metrics': [u'accuracy', u'precision_recall_fscore'], u'_num_kv_servers': u'auto', u'mini_batch_size': u'1000'}
# [08/16/2020 12:58:40 WARNING 140692203804480] Loggers have already been setup.
# [08/16/2020 12:58:41 INFO 140692203804480] Launching parameter server for role scheduler
# [08/16/2020 12:58:41 INFO 140692203804480] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/6abbb840-99c0-4ce6-8575-811cc773d0fb', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/6abbb840-99c0-4ce6-8575-811cc773d0fb', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'randomcutforest-2020-08-16-12-54-52-406', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-121-74.ec2.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/e2dc74d4-9bec-44e8-b5c4-2ba65b0eae76', 'PWD': '/', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:308961792850:training-job/randomcutforest-2020-08-16-12-54-52-406', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [08/16/2020 12:58:41 INFO 140692203804480] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/6abbb840-99c0-4ce6-8575-811cc773d0fb', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/6abbb840-99c0-4ce6-8575-811cc773d0fb', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '1', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.121.74', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'randomcutforest-2020-08-16-12-54-52-406', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-121-74.ec2.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/e2dc74d4-9bec-44e8-b5c4-2ba65b0eae76', 'DMLC_ROLE': 'scheduler', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:308961792850:training-job/randomcutforest-2020-08-16-12-54-52-406', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [08/16/2020 12:58:41 INFO 140692203804480] Launching parameter server for role server
# [08/16/2020 12:58:41 INFO 140692203804480] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/6abbb840-99c0-4ce6-8575-811cc773d0fb', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/6abbb840-99c0-4ce6-8575-811cc773d0fb', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'randomcutforest-2020-08-16-12-54-52-406', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-121-74.ec2.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/e2dc74d4-9bec-44e8-b5c4-2ba65b0eae76', 'PWD': '/', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:308961792850:training-job/randomcutforest-2020-08-16-12-54-52-406', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [08/16/2020 12:58:41 INFO 140692203804480] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/6abbb840-99c0-4ce6-8575-811cc773d0fb', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/6abbb840-99c0-4ce6-8575-811cc773d0fb', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '1', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.121.74', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'randomcutforest-2020-08-16-12-54-52-406', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-121-74.ec2.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/e2dc74d4-9bec-44e8-b5c4-2ba65b0eae76', 'DMLC_ROLE': 'server', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:308961792850:training-job/randomcutforest-2020-08-16-12-54-52-406', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [08/16/2020 12:58:41 INFO 140692203804480] Environment: {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/6abbb840-99c0-4ce6-8575-811cc773d0fb', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/6abbb840-99c0-4ce6-8575-811cc773d0fb', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_WORKER': '1', 'SAGEMAKER_HTTP_PORT': '8080', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.121.74', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'randomcutforest-2020-08-16-12-54-52-406', 'HOME': '/root', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-121-74.ec2.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/e2dc74d4-9bec-44e8-b5c4-2ba65b0eae76', 'DMLC_ROLE': 'worker', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:308961792850:training-job/randomcutforest-2020-08-16-12-54-52-406', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# Process 32 is a shell:scheduler.
# Process 33 is a shell:server.
# Process 1 is a worker.
# [08/16/2020 12:58:41 INFO 140692203804480] Using default worker.
# [08/16/2020 12:58:41 INFO 140692203804480] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [08/16/2020 12:58:41 INFO 140692203804480] Checkpoint loading and saving are disabled.
# [08/16/2020 12:58:41 INFO 140692203804480] Verifying hyperparamemters...
# [08/16/2020 12:58:41 INFO 140692203804480] Hyperparameters are correct.
# [08/16/2020 12:58:41 INFO 140692203804480] Validating that feature_dim agrees with dimensions in training data...
# [08/16/2020 12:58:41 INFO 140692203804480] feature_dim is correct.
# [08/16/2020 12:58:41 INFO 140692203804480] Validating memory limits...
# [08/16/2020 12:58:41 INFO 140692203804480] Available memory in bytes: 15274057728
# [08/16/2020 12:58:41 INFO 140692203804480] Estimated sample size in bytes: 614400
# [08/16/2020 12:58:41 INFO 140692203804480] Estimated memory needed to build the forest in bytes: 3072000
# [08/16/2020 12:58:41 INFO 140692203804480] Memory limits validated.
# [08/16/2020 12:58:41 INFO 140692203804480] Starting cluster sharing facilities...
# [08/16/2020 12:58:41 INFO 140692203804480] Create Store: dist_async
# [I 20-08-16 12:58:41] >>> starting FTP server on 0.0.0.0:8999, pid=1 <<<
# [08/16/2020 12:58:41 INFO 140690799757056] >>> starting FTP server on 0.0.0.0:8999, pid=1 <<<
# [I 20-08-16 12:58:41] poller: <class 'pyftpdlib.ioloop.Epoll'>
# [08/16/2020 12:58:41 INFO 140690799757056] poller: <class 'pyftpdlib.ioloop.Epoll'>
# [I 20-08-16 12:58:41] masquerade (NAT) address: None
# [08/16/2020 12:58:41 INFO 140690799757056] masquerade (NAT) address: None
# [I 20-08-16 12:58:41] passive ports: None
# [08/16/2020 12:58:41 INFO 140690799757056] passive ports: None
# [I 20-08-16 12:58:41] use sendfile(2): False
# [08/16/2020 12:58:41 INFO 140690799757056] use sendfile(2): False
# [08/16/2020 12:58:42 INFO 140692203804480] Cluster sharing facilities started.
# [08/16/2020 12:58:42 INFO 140692203804480] Verifying all workers are accessible...
# [08/16/2020 12:58:42 INFO 140692203804480] All workers accessible.
# [08/16/2020 12:58:42 INFO 140692203804480] Initializing Sampler...
# [08/16/2020 12:58:42 INFO 140692203804480] Sampler correctly initialized.
# #metrics {"Metrics": {"initialize.time": {"count": 1, "max": 782.465934753418, "sum": 782.465934753418, "min": 782.465934753418}}, "EndTime": 1597582722.161024, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "RandomCutForest"}, "StartTime": 1597582721.37259}
#
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1597582722.161237, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "RandomCutForest"}, "StartTime": 1597582722.161201}
#
# [2020-08-16 12:58:42.161] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 788, "num_examples": 1, "num_bytes": 28000}
# [08/16/2020 12:58:42 INFO 140692203804480] Sampling training data...
# [2020-08-16 12:58:42.200] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 38, "num_examples": 22, "num_bytes": 604800}
# [08/16/2020 12:58:42 INFO 140692203804480] Sampling training data completed.
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "update.time": {"count": 1, "max": 48.10190200805664, "sum": 48.10190200805664, "min": 48.10190200805664}}, "EndTime": 1597582722.209712, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "RandomCutForest"}, "StartTime": 1597582722.161131}
#
# [08/16/2020 12:58:42 INFO 140692203804480] Early stop condition met. Stopping training.
# [08/16/2020 12:58:42 INFO 140692203804480] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 22, "sum": 22.0, "min": 22}, "Number of Batches Since Last Reset": {"count": 1, "max": 22, "sum": 22.0, "min": 22}, "Number of Records Since Last Reset": {"count": 1, "max": 21600, "sum": 21600.0, "min": 21600}, "Total Batches Seen": {"count": 1, "max": 22, "sum": 22.0, "min": 22}, "Total Records Seen": {"count": 1, "max": 21600, "sum": 21600.0, "min": 21600}, "Max Records Seen Between Resets": {"count": 1, "max": 21600, "sum": 21600.0, "min": 21600}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1597582722.210243, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "RandomCutForest", "epoch": 0}, "StartTime": 1597582722.161578}
#
# [08/16/2020 12:58:42 INFO 140692203804480] #throughput_metric: host=algo-1, train throughput=442597.078566 records/second
# [08/16/2020 12:58:42 INFO 140692203804480] Master node: building Random Cut Forest...
# [08/16/2020 12:58:42 INFO 140692203804480] Gathering samples...
# [08/16/2020 12:58:42 INFO 140692203804480] 21600 samples gathered
# [08/16/2020 12:58:42 INFO 140692203804480] Building Random Cut Forest...
# [08/16/2020 12:58:42 INFO 140692203804480] Random Cut Forest built:
#
# ForestInfo{num_trees: 50, num_samples_in_forest: 21600, num_samples_per_tree: 432, sample_dim: 3, shingle_size: 1, trees_num_nodes: [135, 363, 553, 255, 305, 545, 435, 223, 425, 515, 131, 379, 709, 355, 797, 781, 765, 507, 705, 775, 299, 665, 741, 347, 413, 605, 503, 275, 535, 675, 137, 427, 385, 163, 209, 525, 531, 663, 765, 773, 419, 731, 771, 501, 553, 727, 567, 277, 645, 725, ], trees_depth: [14, 18, 19, 14, 16, 18, 19, 17, 22, 18, 15, 21, 18, 19, 22, 20, 21, 18, 23, 21, 21, 19, 21, 16, 18, 20, 17, 14, 18, 23, 13, 19, 15, 16, 15, 16, 22, 22, 20, 22, 19, 22, 22, 19, 17, 20, 21, 17, 17, 22, ], max_num_nodes: 797, min_num_nodes: 131, avg_num_nodes: 504, max_tree_depth: 23, min_tree_depth: 13, avg_tree_depth: 18, mem_size: 3429008}
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 26.88312530517578, "sum": 26.88312530517578, "min": 26.88312530517578}, "model.bytes": {"count": 1, "max": 3429008, "sum": 3429008.0, "min": 3429008}, "fit_model.time": {"count": 1, "max": 13.046979904174805, "sum": 13.046979904174805, "min": 13.046979904174805}}, "EndTime": 1597582722.237431, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "RandomCutForest"}, "StartTime": 1597582722.20983}
#
# [08/16/2020 12:58:42 INFO 140692203804480] Master node: Serializing the RandomCutForest model
# #metrics {"Metrics": {"serialize_model.time": {"count": 1, "max": 35.80307960510254, "sum": 35.80307960510254, "min": 35.80307960510254}}, "EndTime": 1597582722.273341, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "RandomCutForest"}, "StartTime": 1597582722.237495}
#
# [08/16/2020 12:58:42 INFO 140692203804480] Test data is not provided.
# [08/16/2020 12:58:42 INFO 140690799757056] >>> shutting down FTP server (0 active fds) <<<
# [I 20-08-16 12:58:42] >>> shutting down FTP server (0 active fds) <<<
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 1487.7469539642334, "sum": 1487.7469539642334, "min": 1487.7469539642334}, "setuptime": {"count": 1, "max": 562.6721382141113, "sum": 562.6721382141113, "min": 562.6721382141113}}, "EndTime": 1597582722.288455, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "RandomCutForest"}, "StartTime": 1597582722.273412}
#
# Training seconds: 101
# Billable seconds: 101

# %%
rcf_inference = rcf.deploy(
    initial_instance_count=1,
    instance_type='ml.m4.xlarge',
)
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# -----------

# %% [markdown]
# ### Prediction (Getting anomaly scores)
#
# Set the serializer and predict the anomaly score.

# %%
from sagemaker.predictor import csv_serializer, json_deserializer

rcf_inference.content_type = 'text/csv'
rcf_inference.serializer = csv_serializer
rcf_inference.accept = 'application/json'
rcf_inference.deserializer = json_deserializer

# %%
results = rcf_inference.predict(s.to_numpy())

# %% [markdown]
# Let's look at the distribution of our anomaly score.

# %%
results_pd = pd.DataFrame(results['scores'])
results_pd.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbd84e372e8>]],
#       dtype=object)

# %% [markdown]
# ### Check the result
#
# We can find the algorthim is detecting anomalies with the change and deviation of each feature value instead of using a fixed threshold.

# %%
plt.figure(figsize=(20,5))
plt.plot(s)
threshold = 4.5
anomalous = s[list((results_pd > threshold)['score'])]
plt.scatter(x= anomalous.index, y=anomalous['urls'].values, c='red')
plt.scatter(x= anomalous.index, y=anomalous['users'].values, c='blue')
plt.scatter(x= anomalous.index, y=anomalous['clicks'].values, c='black')
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.plot(s["2012-03-13 08:00:00":"2012-03-13 23:00:00"])
threshold = 4.5
anomalous = s[list((results_pd > threshold)['score'])]["2012-03-13 08:00:00":"2012-03-13 23:00:00"]
plt.scatter(x= anomalous.index, y=anomalous['urls'].values, c='red')
plt.scatter(x= anomalous.index, y=anomalous['users'].values, c='blue')
plt.scatter(x= anomalous.index, y=anomalous['clicks'].values, c='black')
plt.show()

# %% [markdown]
# To examine the relationship between anomaly scores and feature deviations more intuitively, let's plot the the residuals of clicks and users. Below graph show this changes. We can understand anomly socres were returned not only by residual or just the amount of the value.

# %%
plt.figure(figsize=(20,5))
plt.plot(s['clicks']-s['users']["2012-03-13 08:00:00":"2012-03-13 23:00:00"])
plt.scatter(x= anomalous.index, y=anomalous['clicks'].values - anomalous['users'].values, c='blue')
plt.show()

# %% [markdown]
# Zoom in arount 6th March again.

# %%
plt.figure(figsize=(20,7))
plt.plot(s["2012-03-05 21:30:00":"2012-03-06 17:30:00"])
threshold = 4.5
anomalous = s[list((results_pd > threshold)['score'])]["2012-03-05 21:30:00":"2012-03-06 17:30:00"]
plt.scatter(x= anomalous.index, y=anomalous['urls'].values, c='red')
plt.scatter(x= anomalous.index, y=anomalous['users'].values, c='blue')
plt.scatter(x= anomalous.index, y=anomalous['clicks'].values, c='black')
plt.plot(pd.DataFrame([58.5]*len(anomalous.index)).set_index(anomalous.index))
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.plot(s['clicks']-s['users']["2012-03-05 21:30:00":"2012-03-06 17:30:00"])
plt.scatter(x= anomalous.index, y=anomalous['clicks'].values - anomalous['users'].values, c='blue')
plt.show()
